# %%
import os
import shutil
import PIL
import matplotlib.pyplot as plt
from ultralytics import YOLO
import random
import dill
import torch
import cv2
import numpy as np
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
import cv2
import torch.nn.functional as F

# %%
model_type = "DPT_Hybrid"  # Choose model type as per requirements
midas = torch.hub.load("intel-isl/MiDaS", model_type)
midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")
# Set the appropriate transform for the chosen model type
if model_type in ["DPT_Large", "DPT_Hybrid"]:
    transform = midas_transforms.dpt_transform
else:
    transform = midas_transforms.small_transform
# Set the model to evaluation mode if needed
for param in midas.parameters():
    param.requires_grad = False
# Out:
# Using cache found in /home/aditya/.cache/torch/hub/intel-isl_MiDaS_master
# /home/aditya/anaconda3/lib/python3.12/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/aditya/anaconda3/lib/python3.12/site-packages/timm/models/_factory.py:117: UserWarning: Mapping deprecated model name vit_base_resnet50_384 to current vit_base_r50_s16_384.orig_in21k_ft_in1k.
#   model = create_fn(
# Using cache found in /home/aditya/.cache/torch/hub/intel-isl_MiDaS_master

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AbsoluteDepthModel(nn.Module):
    def __init__(self, midas_model):
        super(AbsoluteDepthModel, self).__init__()
        self.midas_model = midas_model
        
        # 1x1 Convolution layers to learn pixel-wise transformations
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=1),  # Input channels = 1 (depth map)
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=1),
            nn.ReLU(),
            nn.Conv2d(32, 1, kernel_size=1) # Output channels = 1 (absolute depth)
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        # Step 1: Get relative inverse depth prediction from MiDas
        relative_depth = self.midas_model(x)  # Shape: (batch, 1, H, W)
        
        
        
        # Step 3: Resize depth map to desired dimensions
        resized_depth = F.interpolate(
            relative_depth.unsqueeze(1),  # Add channel dimension
            size=(352, 1216),
            mode="bicubic",
            align_corners=False
        )
        
        # Step 4: Apply 1x1 convolution for pixel-wise transformation
        absolute_depth = self.conv(resized_depth)
        absolute_depth = self.relu(absolute_depth)  # Ensure non-negative depth
        
        return absolute_depth.squeeze(1)  # Shape: (batch, H, W)

# %%
depth_model = AbsoluteDepthModel(midas)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
depth_model = depth_model.to(device)
state_dict = torch.load('depth.pth', weights_only=True)
depth_model.load_state_dict(state_dict)
# Out:
# True
# <All keys matched successfully>

# %%
def depth_predict(image_in,test_image,point):
    with torch.no_grad():
        image_in=image_in.to('cuda')
        output=depth_model(image_in)
        output = torch.nn.functional.interpolate(
            output.unsqueeze(1),
            size=np.array(test_image).shape[:2],
            mode="bicubic",
            align_corners=False,
        ).squeeze()
    predictions=output.cpu().numpy()
    
    # print(point[1],point[0])
    x=int(point[0])
    y=int(point[1])

    return (predictions[y,x])

# %%
K = np.array([
        [721.5377, 0.0, 596.5593],
        [0.0, 721.5377, 149.854],
        [0.0, 0.0, 1.0]
    ])

# %%
def image_to_camera_coords(u, v, z, intrinsic_matrix):
    """
    Convert image coordinates (u, v) and depth z to 3D camera coordinates (x, y, z).
    
    Parameters:
        u (float): Image coordinate u (pixel column).
        v (float): Image coordinate v (pixel row).
        z (float): Depth value in meters.
        intrinsic_matrix (numpy.ndarray): 3x3 camera intrinsic matrix.
        
    Returns:
        numpy.ndarray: 3D point (x, y, z) in the camera coordinate frame.
    """
    # Intrinsic matrix components
    fx = intrinsic_matrix[0, 0]
    fy = intrinsic_matrix[1, 1]
    cx = intrinsic_matrix[0, 2]
    cy = intrinsic_matrix[1, 2]
    
    # Calculate camera coordinates
    x = (u - cx) * z / fx
    y = (v - cy) * z / fy
    return np.array([x, y, z])

# %%
# Load the YOLO model
class_model = YOLO('/yolo.pt')

# Load images
images = os.listdir("/Dataset/image")

# Randomly shuffle and sample images
random.shuffle(images)
random_images = random.sample(images, 20)

# Define the output video parameters
output_video_path = "depth_video.avi"
frame_width = 1280  # Define frame width
frame_height = 720  # Define frame height
fps = 1  # Frames per second
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Codec

# Initialize VideoWriter
video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

for img in images:
    # Predict using the YOLO model
    results = class_model.predict(source=f"/Dataset/image/{img}", imgsz=640, conf=0.25)
    
    # Load the image for plotting
    image_path = f"/Dataset/image/{img}"
    image = cv2.imread(image_path)
    test_image = Image.open(image_path)
    image_in = transform(np.array(test_image))
    
    for result in results:
        for detection in result.boxes:
            x1, y1, x2, y2 = detection.xyxy[0].tolist()  
            x_center = (x1 + x2) / 2
            y_center = (y1 + y2) / 2
            label = result.names[int(detection.cls)]
            
            # Predict depth at the center of the detection
            depth = depth_predict(image_in, test_image, (x_center, y_center)) 
            # if depth>10:
            #     depth=2.0
            
            # Convert to camera coordinates
            x, y, z = image_to_camera_coords(x_center, y_center, depth, K)
            label_text = f"{label}: ({x:.1f}, {y:.1f}, {z:.2f})"
            print(label_text)
            
            # Write label, center coordinates, and depth on the image
            cv2.putText(image, label_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.7, (255, 0, 0), 2, cv2.LINE_AA)  # Green text
            
            # Draw a circle at the center of the detected object
            cv2.circle(image, (int(x_center), int(y_center)), 5, (255, 0, 0), -1)  # Green dot with radius 5
            plt.figure(figsize=(20,10))
            # plt.imshow(image)
        # break
    # break
    # Resize the image to the output video frame size
    resized_frame = cv2.resize(image, (frame_width, frame_height))
    # Write the frame to the video
    video_writer.write(resized_frame)

# Release the video writer
video_writer.release()
print(f"Video saved at {output_video_path}")
# Out:
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000098_image_02.png: 192x640 8 cars, 1 van, 41.8ms
# Speed: 2.9ms preprocess, 41.8ms inference, 100.2ms postprocess per image at shape (1, 3, 192, 640)
# car: (6.6, 2.0, 14.20)
# car: (-10.1, 1.6, 15.28)
# car: (-8.8, 1.2, 14.80)
# car: (-6.1, 1.1, 15.14)
# car: (3.3, 0.5, 16.95)
# van: (-3.7, 0.5, 16.16)
# car: (0.8, 0.4, 17.12)
# car: (-4.6, 0.7, 15.73)
# car: (-4.2, 0.7, 15.98)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000083_image_02.png: 192x640 2 cars, 7.9ms
# Speed: 0.8ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.0, 0.6, 16.11)
# car: (-1.6, 0.4, 17.31)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_29_drive_0026_sync_image_0000000047_image_02.png: 192x640 3 cars, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.2, 0.5, 16.39)
# car: (-5.6, 0.3, 16.61)
# car: (-0.4, 0.2, 17.02)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000773_image_02.png: 192x640 4 cars, 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.5, 1.2, 14.42)
# car: (1.6, 0.1, 16.99)
# car: (0.1, 0.6, 14.82)
# car: (3.6, -0.1, 17.18)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000689_image_02.png: 192x640 3 cars, 8.0ms
# Speed: 0.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.1, 0.4, 16.77)
# car: (-3.5, 0.4, 17.12)
# car: (-5.8, 0.2, 17.14)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_28_drive_0037_sync_image_0000000059_image_02.png: 192x640 5 pedestrians, 3 cyclists, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# /tmp/ipykernel_95687/3269850436.py:54: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20,10))
# pedestrian: (-9.3, 1.8, 15.01)
# cyclist: (4.8, 1.6, 14.96)
# cyclist: (11.8, 1.5, 16.08)
# cyclist: (9.0, 1.3, 16.78)
# pedestrian: (8.1, 0.9, 17.22)
# pedestrian: (8.7, 1.0, 17.13)
# pedestrian: (-0.1, 0.6, 16.93)
# pedestrian: (8.2, 0.9, 17.16)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000599_image_02.png: 192x640 5 cars, 2 miscs, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# misc: (-8.5, 0.5, 15.72)
# car: (1.3, 0.8, 15.59)
# misc: (-2.6, -0.0, 17.29)
# car: (-4.1, 0.8, 15.63)
# car: (2.8, 0.5, 16.81)
# car: (-3.3, 0.6, 16.04)
# car: (4.6, 0.4, 17.06)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000185_image_02.png: 192x640 7 cars, 2 vans, 1 truck, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.6, 2.1, 14.12)
# car: (-6.4, 1.4, 14.61)
# car: (5.5, 1.4, 14.63)
# car: (-2.5, 0.8, 15.23)
# car: (3.9, 0.8, 14.63)
# van: (8.2, -0.0, 17.05)
# car: (1.2, 0.5, 16.48)
# van: (10.0, -0.0, 17.24)
# truck: (7.2, -0.5, 23.80)
# car: (-11.6, 2.3, 14.71)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000188_image_02.png: 192x640 4 cars, 1 cyclist, 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.6, 0.6, 15.51)
# car: (-1.3, 0.6, 16.25)
# car: (0.4, 0.4, 16.96)
# cyclist: (2.3, 0.5, 16.87)
# car: (2.1, 0.2, 17.26)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000320_image_02.png: 192x640 9 cars, 4 vans, 1 misc, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (7.7, 2.3, 14.31)
# car: (-9.0, 1.4, 15.00)
# car: (4.3, 0.7, 16.36)
# van: (1.4, 0.4, 17.19)
# car: (-5.5, 0.6, 15.96)
# car: (7.1, 1.2, 14.70)
# car: (5.9, 1.0, 14.68)
# car: (-3.0, 0.5, 16.58)
# car: (-3.8, 0.6, 16.51)
# van: (0.8, 0.2, 17.27)
# van: (-1.8, 0.2, 17.27)
# misc: (-4.6, 1.0, 14.62)
# van: (-10.5, 2.0, 14.72)
# car: (-10.5, 2.0, 14.72)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000200_image_02.png: 192x640 4 cars, 1 cyclist, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-6.8, 1.4, 14.42)
# car: (-3.5, 1.0, 15.53)
# car: (-0.7, 0.6, 16.75)
# car: (1.2, 0.4, 17.40)
# cyclist: (2.0, 0.7, 17.03)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0002_sync_image_0000000023_image_02.png: 192x640 1 cyclist, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# cyclist: (8.6, 1.5, 14.51)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000056_image_02.png: 192x640 6 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.7, 0.7, 14.84)
# car: (-11.0, 1.2, 14.66)
# car: (-2.6, 0.5, 16.59)
# car: (-8.4, 0.8, 14.72)
# car: (-7.0, 0.5, 14.96)
# car: (-7.5, 0.7, 14.84)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0020_sync_image_0000000038_image_02.png: 192x640 6 cars, 1 van, 1 cyclist, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (-3.9, 1.1, 15.86)
# van: (-2.9, 0.4, 16.77)
# cyclist: (6.2, 0.7, 15.78)
# car: (-1.5, 1.0, 15.88)
# car: (-1.8, 0.5, 16.32)
# car: (-1.7, 0.4, 17.38)
# car: (-1.1, 0.2, 17.83)
# car: (-1.7, 0.4, 16.41)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000170_image_02.png: 192x640 2 cars, 1 van, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.6, 0.5, 17.25)
# van: (0.1, 0.5, 16.91)
# car: (0.1, 0.5, 16.91)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000239_image_02.png: 192x640 11 cars, 2 vans, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (8.7, 2.1, 14.69)
# car: (-5.1, 1.7, 14.70)
# van: (-3.2, 0.8, 15.03)
# car: (4.7, 1.4, 14.65)
# truck: (1.3, -0.1, 17.54)
# car: (10.6, 0.6, 14.39)
# car: (-1.6, 0.6, 16.35)
# car: (8.1, 0.6, 15.98)
# car: (7.2, 0.5, 16.32)
# car: (-2.1, 0.8, 15.85)
# car: (9.1, 0.6, 14.89)
# car: (5.8, 0.3, 16.77)
# van: (5.7, 0.2, 16.73)
# car: (11.9, 0.8, 14.57)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000149_image_02.png: 192x640 9 cars, 1 pedestrian, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (10.2, 2.1, 14.44)
# car: (-1.8, 1.2, 14.61)
# car: (6.3, 0.7, 15.19)
# car: (0.8, 0.5, 16.10)
# car: (5.8, 0.5, 15.38)
# car: (1.5, 0.4, 16.40)
# car: (-11.1, 2.0, 14.53)
# car: (5.5, 0.4, 15.96)
# car: (2.9, 0.2, 16.98)
# pedestrian: (6.3, 0.2, 15.31)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0079_sync_image_0000000026_image_02.png: 192x640 1 car, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-1.5, 0.4, 16.07)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000545_image_02.png: 192x640 9 cars, 2 miscs, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-5.3, 1.4, 14.92)
# car: (0.1, 0.7, 15.63)
# car: (-8.6, 1.2, 14.71)
# car: (-3.2, 0.7, 15.99)
# misc: (-1.6, -0.0, 17.09)
# car: (-11.6, 1.7, 14.63)
# car: (-2.4, 0.5, 16.49)
# car: (-1.9, 0.4, 16.77)
# car: (-5.3, 0.7, 14.67)
# car: (-5.7, 0.6, 14.50)
# misc: (-1.2, -0.0, 17.10)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000356_image_02.png: 192x640 7 cars, 2 vans, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (8.4, 2.3, 14.58)
# van: (3.4, 0.4, 17.20)
# car: (-6.8, 0.9, 14.88)
# car: (-5.6, 0.8, 15.39)
# car: (-5.1, 0.7, 15.85)
# van: (-3.0, 0.2, 16.96)
# car: (1.4, 0.6, 17.12)
# car: (-2.8, 0.5, 16.62)
# car: (-3.9, 0.6, 16.22)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000446_image_02.png: 192x640 1 truck, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.2, 0.0, 17.40)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000737_image_02.png: 192x640 3 cars, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.9, 0.2, 16.41)
# car: (-0.7, 0.3, 16.38)
# car: (-0.0, -0.0, 17.16)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000014_image_02.png: 192x640 9 cars, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (5.4, 0.9, 14.56)
# car: (-10.8, 1.7, 14.46)
# car: (-8.7, 0.7, 14.73)
# car: (2.8, 0.5, 16.29)
# car: (-7.6, 0.7, 14.84)
# car: (-5.5, 0.4, 15.93)
# car: (2.2, 0.4, 16.19)
# car: (-3.1, 0.0, 17.54)
# car: (-6.5, 0.6, 14.79)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000605_image_02.png: 192x640 5 cars, 2 miscs, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# misc: (-9.6, 0.5, 15.42)
# car: (-5.7, 1.1, 14.97)
# car: (1.7, 0.8, 16.04)
# misc: (-3.4, 0.0, 17.40)
# car: (-4.5, 0.8, 15.97)
# car: (3.4, 0.6, 16.86)
# car: (5.3, 0.4, 17.06)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_29_drive_0026_sync_image_0000000020_image_02.png: 192x640 5 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.4, 2.3, 14.71)
# car: (-10.1, 0.7, 14.92)
# car: (-5.3, 0.2, 16.51)
# car: (-1.4, 0.3, 16.63)
# car: (-0.4, 0.1, 16.84)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000377_image_02.png: 192x640 1 car, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.4, 0.0, 17.40)
# car: (-3.8, 0.4, 17.26)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0002_sync_image_0000000041_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000128_image_02.png: 192x640 2 cars, 1 van, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-5.9, 1.2, 15.02)
# car: (0.0, 0.5, 16.59)
# van: (0.0, 0.5, 16.59)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000482_image_02.png: 192x640 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.3, 0.0, 17.45)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000305_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000146_image_02.png: 192x640 12 cars, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (8.4, 2.3, 14.45)
# car: (-9.4, 1.8, 14.40)
# car: (2.8, 1.0, 14.91)
# car: (-8.8, 1.4, 14.62)
# car: (-7.2, 1.1, 14.59)
# car: (-4.9, 0.9, 15.59)
# car: (-11.0, 2.2, 14.64)
# car: (1.9, 0.7, 16.23)
# car: (-4.2, 0.6, 15.79)
# car: (1.2, 0.3, 17.05)
# car: (-4.5, 0.7, 15.72)
# car: (-2.6, 0.4, 16.52)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_29_drive_0026_sync_image_0000000014_image_02.png: 192x640 5 cars, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.5, 2.3, 14.87)
# car: (-1.8, 0.3, 16.61)
# car: (-5.1, 0.2, 16.75)
# car: (-0.5, 0.2, 16.92)
# car: (-12.2, 0.7, 15.99)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000251_image_02.png: 192x640 6 cars, 2 vans, 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# van: (-8.7, 1.5, 14.55)
# car: (9.6, 2.5, 14.68)
# truck: (0.1, -0.0, 17.30)
# car: (11.0, 1.1, 14.79)
# car: (-5.7, 1.6, 14.81)
# car: (9.1, 0.9, 15.07)
# car: (6.5, 0.5, 15.69)
# van: (6.2, 0.4, 15.77)
# car: (-4.1, 1.0, 15.10)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000335_image_02.png: 192x640 8 cars, 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-9.1, 0.5, 15.87)
# car: (-0.4, 0.7, 16.05)
# car: (-4.1, 1.4, 15.10)
# car: (-2.9, 0.8, 15.97)
# car: (-1.7, 0.4, 16.83)
# car: (-2.2, 0.5, 16.37)
# car: (-4.0, 0.4, 16.47)
# car: (-5.7, 0.6, 16.36)
# car: (-3.1, 0.3, 16.21)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000626_image_02.png: 192x640 2 cars, 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# truck: (0.6, 0.0, 17.44)
# car: (-5.7, 0.5, 17.18)
# car: (-5.1, 0.5, 17.16)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000038_image_02.png: 192x640 1 car, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.2, 0.6, 15.91)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000122_image_02.png: 192x640 2 cars, 1 van, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.9, 0.6, 16.40)
# van: (-0.0, 0.4, 16.30)
# car: (-0.0, 0.4, 16.30)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000134_image_02.png: 192x640 4 cars, 1 cyclist, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-6.6, 1.3, 14.61)
# cyclist: (-4.0, 1.0, 15.80)
# car: (-2.6, 0.5, 16.40)
# car: (1.5, 0.3, 16.72)
# car: (0.6, 0.0, 17.44)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0020_sync_image_0000000062_image_02.png: 192x640 4 cars, 1 van, 1 cyclist, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (-2.4, 1.4, 14.66)
# car: (-4.7, 1.2, 15.51)
# cyclist: (3.8, 0.4, 16.75)
# van: (-3.2, 0.4, 16.87)
# car: (-1.7, 0.5, 16.72)
# car: (-1.7, 0.5, 15.50)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000410_image_02.png: 192x640 9 cars, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (7.1, 1.2, 14.33)
# car: (-10.4, 2.0, 14.68)
# car: (-9.4, 1.8, 14.59)
# car: (-5.1, 0.8, 15.61)
# car: (-8.4, 1.3, 14.85)
# car: (1.4, 0.7, 16.08)
# car: (-3.1, 0.5, 16.06)
# car: (-1.1, 0.4, 17.36)
# car: (1.1, 0.5, 16.15)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_29_drive_0026_sync_image_0000000035_image_02.png: 192x640 4 cars, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-4.8, 0.6, 15.93)
# car: (-0.8, 0.3, 16.89)
# car: (-0.1, 0.2, 17.15)
# car: (-5.4, 0.3, 15.95)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000242_image_02.png: 192x640 3 cars, 2 vans, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-3.2, 0.5, 17.10)
# car: (-1.4, 0.3, 17.53)
# car: (0.3, 0.4, 16.76)
# van: (-2.2, 0.3, 17.46)
# van: (0.3, 0.4, 16.75)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000080_image_02.png: 192x640 2 cars, 1 pedestrian, 1 misc, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (11.6, 1.1, 14.63)
# pedestrian: (8.6, 1.4, 15.40)
# car: (11.3, 0.6, 14.67)
# misc: (-3.4, 1.2, 15.75)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000623_image_02.png: 192x640 8 cars, 1 misc, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# misc: (-9.2, 0.1, 15.56)
# car: (2.9, 0.7, 15.77)
# car: (4.7, 0.5, 16.75)
# car: (-6.2, 0.6, 16.47)
# car: (-6.9, 0.8, 16.39)
# car: (-11.4, 1.1, 15.60)
# car: (-12.4, 1.3, 15.33)
# car: (5.9, 0.3, 16.16)
# car: (5.9, 0.3, 16.22)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000383_image_02.png: 192x640 8 cars, 1 van, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.9, 1.4, 14.71)
# car: (-3.6, 1.1, 14.61)
# car: (-0.6, 0.6, 15.87)
# car: (-5.9, 0.8, 15.68)
# car: (-8.8, 0.7, 15.36)
# car: (-6.7, 0.6, 15.69)
# car: (-2.4, 0.6, 16.11)
# car: (-1.8, 0.5, 16.61)
# van: (-1.4, 0.2, 16.84)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000164_image_02.png: 192x640 1 car, 1 van, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.1, 0.5, 16.76)
# van: (0.1, 0.5, 16.74)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000335_image_02.png: 192x640 1 van, 1 truck, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (-3.1, 0.8, 16.40)
# truck: (8.2, 0.0, 17.22)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000152_image_02.png: 192x640 9 cars, 1 misc, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.9, 1.7, 15.02)
# car: (-9.9, 1.9, 14.51)
# car: (-6.4, 1.2, 14.89)
# car: (2.6, 0.8, 15.85)
# car: (-5.7, 0.9, 14.72)
# car: (1.5, 0.3, 16.87)
# car: (-5.1, 0.6, 14.74)
# car: (-11.6, 2.3, 14.65)
# car: (-2.8, 0.4, 16.22)
# misc: (-2.5, 0.5, 16.44)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000023_image_02.png: 192x640 10 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (3.1, 0.3, 15.73)
# car: (12.6, -0.1, 16.21)
# car: (-1.9, 0.5, 15.88)
# car: (11.4, -0.2, 16.44)
# car: (8.5, -0.1, 16.53)
# car: (13.3, -0.1, 16.34)
# car: (5.9, -0.1, 16.89)
# car: (1.2, 0.2, 16.67)
# car: (8.2, -0.1, 16.66)
# car: (-0.6, 0.3, 16.69)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000026_image_02.png: 192x640 11 cars, 1 van, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (8.7, 2.0, 14.13)
# car: (-10.0, 2.4, 14.52)
# car: (-7.0, 1.6, 14.77)
# car: (-4.3, 1.0, 15.18)
# car: (3.8, 1.1, 14.78)
# car: (2.6, 0.7, 15.01)
# van: (2.0, 0.0, 17.34)
# car: (-2.0, 0.4, 17.21)
# car: (0.3, 0.3, 17.58)
# car: (0.8, 0.3, 17.54)
# car: (-0.4, 0.3, 17.90)
# car: (1.3, 0.4, 17.32)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000641_image_02.png: 192x640 3 cars, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (3.6, 0.4, 16.39)
# car: (5.2, 0.1, 17.16)
# car: (4.1, 0.2, 16.44)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000404_image_02.png: 192x640 11 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.5, 2.1, 14.60)
# car: (10.0, 1.8, 14.41)
# car: (-8.8, 1.5, 14.43)
# car: (5.1, 0.9, 15.44)
# car: (-8.1, 1.1, 14.83)
# car: (-4.1, 0.6, 16.14)
# car: (1.1, 0.6, 16.48)
# car: (-5.6, 0.9, 14.77)
# car: (11.5, 2.3, 14.44)
# car: (-6.7, 1.0, 14.67)
# car: (-2.7, 0.5, 16.38)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000158_image_02.png: 192x640 1 car, 1 van, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.1, 0.5, 16.50)
# van: (0.1, 0.5, 16.50)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000359_image_02.png: 192x640 11 cars, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.4, 2.4, 14.88)
# car: (-3.9, 1.2, 15.21)
# car: (-0.4, 0.7, 15.90)
# car: (-8.9, 1.2, 14.89)
# car: (-2.1, 0.7, 16.23)
# car: (-6.4, 0.6, 16.37)
# car: (-4.8, 0.7, 15.16)
# car: (-1.5, 0.4, 16.85)
# car: (-1.6, 0.5, 16.53)
# car: (-11.2, 1.9, 14.48)
# car: (-11.5, 1.9, 14.62)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000341_image_02.png: 192x640 10 cars, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (-5.6, 2.0, 14.60)
# car: (-3.4, 1.0, 15.36)
# car: (-0.4, 0.7, 15.61)
# car: (-2.5, 0.6, 16.17)
# car: (-6.3, 0.7, 15.39)
# car: (-1.8, 0.5, 16.49)
# car: (-6.9, 0.6, 15.72)
# car: (-4.0, 0.5, 15.33)
# car: (-10.3, 1.4, 14.61)
# car: (-5.5, 0.5, 16.52)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0113_sync_image_0000000038_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0020_sync_image_0000000023_image_02.png: 192x640 4 cars, 1 van, 1 cyclist, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.6, 2.3, 14.19)
# van: (-2.6, 0.4, 17.04)
# car: (-3.4, 0.9, 16.35)
# car: (-1.2, 0.8, 16.59)
# cyclist: (8.2, 0.9, 14.86)
# car: (-1.7, 0.4, 17.38)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000398_image_02.png: 192x640 12 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.2, 1.8, 14.72)
# car: (8.9, 1.4, 14.80)
# car: (7.3, 1.1, 14.90)
# car: (-10.6, 2.1, 14.22)
# car: (4.1, 0.7, 16.05)
# car: (-6.7, 1.1, 14.93)
# car: (1.1, 0.5, 16.73)
# car: (-3.3, 0.5, 16.05)
# car: (-5.2, 0.7, 14.44)
# car: (-8.7, 1.4, 15.19)
# car: (-2.3, 0.4, 16.62)
# car: (-6.0, 0.9, 14.76)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000761_image_02.png: 192x640 5 cars, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.3, 0.8, 15.10)
# car: (0.0, 0.5, 14.91)
# car: (1.4, 0.2, 16.70)
# car: (1.9, 0.1, 17.15)
# car: (3.2, -0.1, 17.10)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000194_image_02.png: 192x640 11 cars, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.0, 2.4, 14.66)
# car: (5.0, 1.7, 14.69)
# car: (-10.1, 1.4, 14.69)
# car: (-9.0, 1.4, 14.71)
# car: (-7.7, 1.0, 14.58)
# car: (-5.2, 0.6, 16.08)
# car: (2.2, 0.7, 16.21)
# car: (-4.1, 0.4, 16.43)
# car: (1.5, 0.4, 16.76)
# car: (-3.2, 0.4, 16.55)
# car: (-10.9, 1.8, 14.94)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000194_image_02.png: 192x640 2 cars, 1 van, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.1, 0.4, 17.03)
# car: (-2.5, 0.4, 17.70)
# van: (0.1, 0.4, 17.03)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000491_image_02.png: 192x640 7 cars, 3 vans, 1 misc, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.0, 1.9, 14.78)
# misc: (-4.6, 0.6, 16.74)
# van: (-7.2, 0.7, 14.73)
# van: (-3.5, 0.4, 16.84)
# car: (-0.3, 0.4, 16.29)
# car: (-5.8, 0.7, 15.90)
# car: (-2.4, 0.4, 16.66)
# van: (-1.6, 0.1, 16.91)
# car: (-9.1, 0.9, 14.47)
# car: (-1.9, 0.4, 16.72)
# car: (-11.3, 1.6, 14.57)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000674_image_02.png: 192x640 5 cars, 1 truck, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-1.4, -0.0, 17.21)
# car: (-11.8, 0.9, 16.66)
# car: (-10.3, 0.8, 16.81)
# car: (-13.1, 1.0, 16.39)
# car: (-9.5, 0.7, 16.94)
# car: (-8.7, 0.6, 17.03)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000353_image_02.png: 192x640 11 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-5.7, 1.9, 14.74)
# car: (-0.4, 0.7, 15.81)
# car: (-9.7, 2.3, 14.78)
# car: (-3.3, 0.9, 15.70)
# car: (-7.4, 1.0, 14.65)
# car: (-2.0, 0.6, 16.44)
# car: (-4.5, 0.5, 15.43)
# car: (-6.0, 0.6, 16.52)
# car: (-1.4, 0.4, 16.73)
# car: (-8.1, 0.6, 15.66)
# car: (-7.9, 0.8, 15.76)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000293_image_02.png: 192x640 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (12.1, -0.6, 16.14)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000017_image_02.png: 192x640 5 cars, 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.2, 2.2, 14.25)
# car: (2.0, 0.3, 15.88)
# car: (-2.6, 0.5, 16.80)
# car: (7.1, -0.2, 17.19)
# car: (4.8, -0.1, 17.37)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000458_image_02.png: 192x640 1 car, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.0, 0.0, 17.41)
# car: (-5.5, 0.7, 17.09)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000176_image_02.png: 192x640 6 cars, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.5, 2.2, 14.46)
# car: (5.0, 1.5, 14.36)
# car: (-1.0, 0.5, 16.43)
# car: (-0.1, 0.5, 16.78)
# car: (1.3, 0.4, 17.11)
# car: (-11.7, 0.8, 14.83)
# cyclist: (2.4, 0.5, 17.03)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000116_image_02.png: 192x640 4 cars, 3 cyclists, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.1, 1.3, 14.40)
# car: (-5.6, 1.2, 14.69)
# cyclist: (-2.2, 0.6, 16.95)
# car: (-3.1, 0.6, 16.35)
# car: (1.0, 0.3, 17.06)
# cyclist: (-1.7, 0.5, 17.03)
# cyclist: (-1.5, 0.3, 17.29)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000170_image_02.png: 192x640 8 cars, 1 pedestrian, 6 miscs, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.0, 2.5, 14.45)
# misc: (5.7, 2.3, 14.70)
# car: (2.0, 0.7, 16.07)
# misc: (-7.7, 1.9, 14.53)
# misc: (-9.6, 1.7, 14.35)
# misc: (-6.3, 1.6, 14.63)
# car: (-5.1, 0.9, 15.43)
# car: (1.4, 0.6, 16.49)
# car: (-3.6, 0.6, 16.26)
# car: (-5.6, 0.9, 14.99)
# pedestrian: (-11.1, 0.7, 16.20)
# misc: (-5.6, 1.3, 15.00)
# misc: (-5.1, 1.1, 15.15)
# car: (0.9, 0.5, 17.18)
# car: (-4.5, 0.8, 15.77)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000113_image_02.png: 192x640 9 cars, 3 vans, 1 misc, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.1, 2.2, 14.56)
# car: (-6.9, 0.8, 15.25)
# car: (-3.7, 0.8, 15.34)
# car: (1.9, 0.6, 16.06)
# van: (-5.2, 0.5, 16.19)
# car: (-0.1, 0.4, 16.64)
# van: (-3.7, 0.3, 15.19)
# car: (-2.4, 0.5, 16.49)
# car: (-1.7, 0.4, 16.82)
# car: (0.7, 0.3, 16.95)
# van: (-3.0, 0.3, 16.92)
# misc: (-0.4, 0.1, 17.40)
# car: (-1.4, 0.3, 17.01)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000059_image_02.png: 192x640 12 cars, 1 van, 8.3ms
# Speed: 0.7ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-3.5, 1.2, 14.44)
# car: (9.6, 1.3, 14.65)
# car: (6.8, -0.0, 16.02)
# car: (-4.7, 1.0, 14.61)
# car: (1.8, 0.3, 15.90)
# car: (0.3, 0.4, 16.36)
# car: (9.7, -0.2, 16.60)
# car: (10.9, -0.1, 16.65)
# car: (-0.5, 0.1, 16.97)
# van: (13.2, -0.4, 16.78)
# car: (-3.5, 0.7, 14.34)
# car: (-2.5, 0.6, 14.91)
# car: (1.2, 0.3, 16.31)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000164_image_02.png: 192x640 7 cars, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (8.9, 2.1, 14.56)
# car: (4.5, 0.8, 14.64)
# car: (-11.2, 2.6, 14.67)
# car: (0.5, 0.2, 16.71)
# car: (3.6, 0.5, 15.55)
# car: (1.2, 0.2, 16.93)
# car: (2.4, 0.1, 17.11)
# cyclist: (2.4, 0.1, 17.14)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000278_image_02.png: 192x640 10 cars, 1 van, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.8, 2.2, 14.41)
# car: (-8.8, 1.6, 14.70)
# car: (3.4, 1.1, 14.73)
# car: (-6.2, 1.0, 14.78)
# car: (1.9, 0.4, 16.51)
# van: (1.0, -0.0, 17.56)
# car: (-3.7, 0.6, 15.53)
# car: (-3.4, 0.5, 15.67)
# car: (-7.6, 1.2, 14.61)
# car: (-2.5, 0.4, 16.63)
# car: (1.4, 0.3, 17.09)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000212_image_02.png: 192x640 11 cars, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.0, 2.3, 14.66)
# car: (-9.9, 1.7, 14.24)
# car: (2.9, 1.0, 14.86)
# car: (-9.0, 1.6, 14.41)
# car: (-7.3, 1.3, 14.58)
# car: (2.0, 0.8, 15.21)
# car: (-6.5, 1.0, 14.55)
# car: (-3.4, 0.5, 16.24)
# car: (1.5, 0.5, 16.72)
# car: (-2.6, 0.5, 16.40)
# car: (1.0, 0.4, 17.00)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000050_image_02.png: 192x640 7 cars, 1 van, 2 cyclists, 1 misc, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (8.4, 0.5, 14.65)
# car: (-11.8, 1.2, 15.41)
# car: (4.3, 1.0, 14.66)
# car: (-3.5, 0.7, 16.34)
# car: (2.8, 0.8, 14.74)
# car: (1.4, 0.5, 16.26)
# car: (-0.5, 0.4, 16.99)
# misc: (-9.2, 1.1, 15.58)
# car: (0.6, 0.4, 16.76)
# cyclist: (-2.3, 0.5, 16.93)
# cyclist: (-2.8, 0.5, 16.93)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0113_sync_image_0000000026_image_02.png: 192x640 1 car, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# cyclist: (-9.3, 1.8, 14.78)
# car: (-0.2, 1.1, 15.20)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000323_image_02.png: 192x640 5 cars, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-7.3, 0.5, 14.63)
# car: (-0.4, 0.7, 15.61)
# car: (-2.8, 0.9, 15.60)
# car: (-2.2, 0.6, 15.97)
# car: (-1.8, 0.4, 16.35)
# car: (-1.5, 0.3, 16.58)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000119_image_02.png: 192x640 8 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-4.6, 1.4, 14.85)
# car: (10.0, 2.3, 14.70)
# car: (-9.8, 2.5, 14.86)
# car: (4.8, 0.6, 15.57)
# car: (8.7, 1.5, 14.38)
# car: (-3.4, 1.1, 14.71)
# car: (11.2, 0.5, 15.91)
# car: (11.4, 2.1, 14.38)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000722_image_02.png: 192x640 1 van, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# truck: (0.1, -0.2, 17.28)
# van: (-2.0, -0.0, 17.43)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000107_image_02.png: 192x640 11 cars, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.0, 2.4, 14.62)
# car: (5.2, 1.5, 14.77)
# car: (-3.9, 1.7, 14.67)
# car: (11.6, 0.4, 16.03)
# car: (-2.2, 0.8, 15.80)
# car: (4.5, 0.3, 16.41)
# car: (-1.8, 0.7, 15.89)
# car: (5.8, 0.6, 14.84)
# car: (9.9, 0.2, 16.74)
# car: (4.6, 1.0, 14.48)
# car: (0.9, 0.1, 17.21)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000317_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000140_image_02.png: 192x640 8 cars, 2 vans, 1 pedestrian, 1 cyclist, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.7, 2.1, 14.49)
# car: (3.5, 1.6, 14.61)
# van: (-6.9, 1.1, 14.60)
# car: (-9.1, 1.7, 14.66)
# car: (0.6, 0.8, 14.76)
# cyclist: (-1.5, 1.0, 15.93)
# car: (-6.1, 0.9, 15.18)
# car: (-0.3, 0.7, 15.28)
# car: (-5.7, 0.7, 15.59)
# van: (-2.9, 0.3, 16.50)
# car: (-1.0, 0.5, 15.93)
# pedestrian: (3.1, 0.5, 14.66)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000134_image_02.png: 192x640 10 cars, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.6, 2.1, 14.83)
# car: (2.7, 1.0, 14.90)
# car: (-7.9, 1.3, 15.01)
# car: (1.5, 0.7, 15.94)
# car: (-5.0, 0.9, 14.70)
# car: (-6.0, 1.1, 14.50)
# car: (-3.4, 0.7, 16.50)
# car: (-3.3, 0.5, 16.50)
# car: (0.7, 0.3, 17.01)
# car: (1.1, 0.5, 16.34)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000263_image_02.png: 192x640 3 cars, 1 van, 1 truck, 2 miscs, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# misc: (-8.6, 0.5, 15.36)
# misc: (-3.3, 0.4, 16.82)
# car: (-0.2, 0.5, 16.76)
# truck: (-1.7, -0.1, 17.26)
# van: (-4.3, 0.4, 16.81)
# car: (-5.6, 0.7, 16.51)
# car: (-2.4, 0.7, 16.72)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000068_image_02.png: 192x640 3 cars, 1 pedestrian, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (10.4, 0.6, 15.39)
# car: (11.8, 0.7, 14.60)
# car: (1.3, 0.6, 16.90)
# pedestrian: (6.8, 1.6, 14.94)
# cyclist: (6.7, 1.6, 14.66)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000038_image_02.png: 192x640 9 cars, 1 van, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (7.9, 2.0, 14.51)
# car: (-9.9, 2.1, 14.08)
# van: (3.9, 0.0, 16.86)
# car: (2.2, 0.5, 16.89)
# car: (-2.6, 0.5, 16.86)
# car: (1.0, 0.4, 17.02)
# car: (-0.4, 0.4, 17.36)
# car: (0.4, 0.4, 17.30)
# car: (1.8, 0.5, 16.94)
# car: (12.1, 2.2, 14.72)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000449_image_02.png: 192x640 6 cars, 1 van, 2 miscs, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (-5.9, 0.6, 16.37)
# car: (-10.5, 1.7, 14.73)
# car: (-0.4, 0.5, 16.65)
# car: (-2.8, 0.7, 15.98)
# car: (-7.8, 1.1, 14.80)
# car: (-2.3, 0.6, 16.78)
# misc: (-1.5, 0.3, 17.49)
# car: (-11.3, 1.1, 14.61)
# misc: (-3.1, 0.9, 15.98)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0002_sync_image_0000000011_image_02.png: 192x640 2 cyclists, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# cyclist: (3.3, 0.9, 15.27)
# cyclist: (11.2, 1.4, 14.42)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000224_image_02.png: 192x640 5 cars, 1 van, 2 cyclists, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-3.9, 1.4, 14.88)
# van: (6.5, -0.1, 17.06)
# car: (0.4, 0.5, 16.76)
# cyclist: (4.1, 1.2, 15.78)
# cyclist: (3.5, 1.0, 16.12)
# car: (-3.5, 0.5, 16.50)
# car: (3.9, 0.3, 16.97)
# car: (3.9, 0.3, 16.86)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0013_sync_image_0000000110_image_02.png: 192x640 4 cars, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-0.3, 0.6, 16.72)
# car: (-9.8, 0.4, 17.31)
# car: (-8.7, 0.4, 17.43)
# car: (-7.7, 0.4, 17.50)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000203_image_02.png: 192x640 8 cars, 2 vans, 1 truck, 1 misc, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (-10.1, 0.6, 15.49)
# car: (-3.8, 1.0, 15.11)
# car: (-7.0, 0.9, 15.50)
# car: (-1.1, 0.6, 15.85)
# car: (-10.8, 1.8, 14.57)
# car: (-5.6, 0.7, 16.33)
# misc: (-3.0, 0.2, 16.97)
# truck: (-2.6, -0.0, 17.20)
# van: (-3.8, 0.2, 15.24)
# car: (-7.1, 0.6, 15.39)
# car: (-3.2, 0.6, 14.97)
# car: (-1.6, 0.3, 16.05)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000074_image_02.png: 192x640 1 car, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.0, 0.5, 16.12)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000134_image_02.png: 192x640 9 cars, 2 vans, 1 pedestrian, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.5, 1.7, 14.37)
# car: (-8.1, 1.5, 14.79)
# car: (1.4, 1.3, 14.53)
# van: (-6.8, 1.1, 14.72)
# cyclist: (-1.5, 1.1, 15.21)
# car: (-0.5, 0.9, 15.31)
# car: (-6.4, 1.0, 15.30)
# car: (-2.0, 0.7, 15.81)
# car: (-1.3, 0.7, 15.45)
# van: (-3.9, 0.5, 16.40)
# car: (-6.3, 0.9, 15.50)
# car: (-2.3, 0.6, 15.95)
# pedestrian: (1.3, 0.5, 15.00)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000200_image_02.png: 192x640 9 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.2, 2.3, 14.71)
# car: (-10.4, 1.9, 14.63)
# car: (-10.0, 1.5, 14.88)
# car: (2.8, 1.0, 15.21)
# car: (-5.3, 0.6, 15.84)
# car: (-6.9, 0.9, 14.89)
# car: (1.7, 0.6, 16.29)
# car: (-3.9, 0.6, 15.91)
# car: (1.3, 0.5, 16.41)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000110_image_02.png: 192x640 8 cars, 1 van, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.3, 1.9, 14.75)
# car: (4.3, 0.6, 16.40)
# car: (-7.0, 0.9, 14.52)
# van: (-5.3, 0.6, 15.53)
# car: (0.9, 0.4, 16.88)
# car: (-6.1, 0.8, 14.70)
# car: (-10.8, 2.2, 14.75)
# car: (-3.8, 0.5, 16.19)
# car: (0.3, 0.3, 17.11)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000167_image_02.png: 192x640 9 cars, 1 truck, 1 pedestrian, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.2, 2.2, 14.44)
# car: (-4.7, 1.4, 14.94)
# car: (5.9, 1.5, 14.71)
# car: (3.7, 1.0, 15.50)
# car: (-3.0, 1.1, 15.41)
# car: (-2.1, 0.8, 16.41)
# car: (-0.7, 0.6, 16.61)
# car: (1.6, 0.5, 16.96)
# pedestrian: (8.4, 1.0, 14.75)
# car: (3.0, 0.7, 15.89)
# truck: (4.9, -0.2, 17.50)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000035_image_02.png: 192x640 12 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (10.8, -0.3, 16.75)
# car: (-2.3, 0.5, 15.98)
# car: (-0.8, 0.3, 16.50)
# car: (4.4, 0.3, 15.63)
# car: (7.0, -0.2, 17.03)
# car: (1.5, 0.2, 16.59)
# car: (10.3, -0.3, 16.68)
# car: (14.0, -0.4, 16.74)
# car: (4.3, -0.0, 15.68)
# car: (7.5, -0.2, 14.76)
# car: (7.9, -0.3, 17.03)
# car: (0.4, 0.2, 16.67)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000542_image_02.png: 192x640 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.1, 0.2, 17.26)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000377_image_02.png: 192x640 8 cars, 1 van, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-3.0, 0.9, 15.11)
# car: (-7.8, 1.0, 14.79)
# car: (-0.6, 0.6, 15.70)
# car: (-5.1, 0.7, 16.08)
# car: (-6.0, 0.5, 16.32)
# car: (-1.7, 0.4, 16.65)
# car: (-2.3, 0.6, 16.35)
# car: (-11.4, 2.2, 15.00)
# van: (-1.4, 0.1, 16.89)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000092_image_02.png: 192x640 2 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-0.2, 0.6, 16.13)
# car: (-2.7, 0.5, 16.86)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0113_sync_image_0000000044_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0113_sync_image_0000000074_image_02.png: 192x640 2 cars, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (12.2, 1.7, 14.77)
# car: (12.0, 1.5, 15.56)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000230_image_02.png: 192x640 6 cars, 1 van, 2 cyclists, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.3, 2.3, 14.54)
# cyclist: (4.3, 1.3, 15.78)
# car: (-0.3, 0.6, 16.54)
# cyclist: (5.2, 1.6, 14.91)
# van: (6.5, -0.0, 16.75)
# car: (3.7, 0.4, 16.75)
# car: (-4.9, 0.6, 15.62)
# car: (1.0, 0.4, 17.11)
# car: (0.2, 0.5, 16.70)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000509_image_02.png: 192x640 8 cars, 1 van, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.0, 1.4, 14.54)
# car: (-5.4, 1.0, 14.76)
# car: (-0.2, 0.5, 16.07)
# car: (-3.1, 0.6, 16.09)
# van: (-2.3, 0.2, 16.83)
# car: (-7.8, 0.7, 16.04)
# car: (-1.6, 0.3, 16.84)
# car: (-5.3, 0.7, 14.86)
# car: (-4.9, 0.6, 14.79)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0002_sync_image_0000000047_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000092_image_02.png: 192x640 8 cars, 2 cyclists, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (7.2, 2.1, 14.44)
# car: (-4.9, 1.5, 14.61)
# car: (2.5, 0.9, 15.41)
# car: (-3.3, 0.9, 15.69)
# car: (1.4, 0.5, 16.92)
# car: (-2.3, 0.6, 16.73)
# car: (-1.8, 0.5, 17.28)
# cyclist: (-0.6, 0.3, 17.61)
# car: (0.7, 0.4, 17.48)
# cyclist: (-0.8, 0.4, 17.67)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000653_image_02.png: 192x640 2 cars, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (3.2, 0.4, 16.83)
# car: (2.7, 0.3, 17.05)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000662_image_02.png: 192x640 6 cars, 1 truck, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.2, -0.2, 17.37)
# car: (-12.3, 0.8, 16.11)
# car: (-10.9, 0.7, 16.32)
# car: (-9.8, 0.6, 16.76)
# car: (-8.9, 0.5, 16.88)
# car: (-8.1, 0.5, 17.09)
# car: (-7.3, 0.4, 17.19)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000104_image_02.png: 192x640 3 cars, 2 vans, 1 pedestrian, 1 cyclist, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (10.0, 1.3, 14.95)
# cyclist: (5.3, 1.2, 15.89)
# car: (8.2, 0.9, 15.85)
# car: (7.1, 0.8, 15.70)
# van: (5.2, 0.5, 16.29)
# pedestrian: (-8.4, 1.5, 14.69)
# car: (6.5, 0.6, 16.17)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000203_image_02.png: 192x640 9 cars, 3 vans, 1 truck, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 640)
# car: (-1.4, 1.0, 14.68)
# car: (9.3, 2.1, 14.72)
# car: (6.4, 2.0, 14.26)
# van: (11.2, 0.1, 15.89)
# van: (8.7, 0.2, 16.03)
# car: (5.3, 1.0, 14.65)
# car: (0.0, 0.4, 16.49)
# truck: (3.5, -0.3, 18.50)
# car: (4.0, 0.3, 16.65)
# car: (12.7, 0.1, 16.00)
# car: (1.0, 0.2, 16.94)
# car: (7.4, 0.1, 16.71)
# van: (1.2, 0.1, 16.94)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000344_image_02.png: 192x640 6 cars, 3 vans, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# van: (5.3, 0.9, 15.64)
# car: (-10.4, 2.2, 14.65)
# car: (-7.5, 1.0, 14.73)
# van: (1.9, 0.3, 17.11)
# car: (2.8, 1.0, 15.34)
# car: (-4.1, 0.6, 15.76)
# van: (-2.2, 0.2, 16.62)
# car: (-3.5, 0.6, 16.02)
# car: (1.0, 0.5, 17.16)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000008_image_02.png: 192x640 1 car, 1 cyclist, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# cyclist: (5.3, 1.8, 14.89)
# car: (-5.0, 0.8, 14.57)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0005_sync_image_0000000074_image_02.png: 192x640 2 cars, 1 pedestrian, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 640)
# car: (11.7, 0.5, 15.41)
# car: (12.2, 0.8, 14.84)
# pedestrian: (8.3, 1.5, 15.00)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000122_image_02.png: 192x640 8 cars, 1 van, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.0, 2.3, 14.36)
# van: (-8.9, 1.4, 15.03)
# car: (7.0, 0.9, 14.59)
# car: (1.5, 0.7, 15.71)
# car: (-6.4, 1.2, 14.01)
# car: (-4.4, 0.9, 14.60)
# car: (-5.9, 1.1, 14.47)
# car: (0.9, 0.6, 16.08)
# car: (-2.7, 0.6, 16.25)
#
# ...
# car: (-8.1, 2.3, 14.15)
# car: (-4.1, 1.3, 14.58)
# car: (6.4, 0.9, 14.70)
# car: (-2.6, 1.0, 15.36)
# car: (1.9, 0.7, 15.95)
# car: (-2.0, 0.8, 15.59)
# car: (5.8, 0.5, 14.82)
# car: (3.3, 0.5, 16.42)
# car: (2.3, 0.6, 15.87)
# car: (-1.6, 0.6, 16.31)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0002_sync_image_0000000053_image_02.png: 192x640 (no detections), 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000422_image_02.png: 192x640 1 truck, 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (0.0, 0.1, 17.38)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000413_image_02.png: 192x640 13 cars, 1 van, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-7.1, 2.2, 14.62)
# car: (-2.6, 0.9, 15.57)
# car: (-10.6, 1.1, 14.79)
# car: (-0.1, 0.5, 16.23)
# car: (-8.4, 1.2, 14.53)
# car: (-5.0, 0.8, 15.82)
# van: (-1.5, 0.2, 16.92)
# car: (-3.9, 0.6, 16.45)
# car: (-6.1, 0.6, 16.15)
# car: (-2.1, 0.6, 15.91)
# car: (-8.1, 0.7, 14.69)
# car: (-11.9, 1.7, 14.76)
# car: (-5.1, 0.5, 16.02)
# car: (-11.4, 0.8, 15.05)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000212_image_02.png: 192x640 1 car, 1 van, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.0, 0.5, 17.22)
# van: (0.0, 0.5, 17.30)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000170_image_02.png: 192x640 5 cars, 1 cyclist, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (6.3, 1.6, 14.63)
# car: (3.8, 0.9, 14.92)
# car: (-0.3, 0.4, 16.75)
# car: (0.6, 0.4, 16.97)
# car: (1.9, 0.3, 17.27)
# cyclist: (2.6, 0.4, 17.11)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_29_drive_0026_sync_image_0000000026_image_02.png: 192x640 5 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.1, 0.7, 15.54)
# car: (-5.5, 0.2, 16.51)
# car: (-1.2, 0.2, 16.71)
# car: (-0.3, 0.1, 17.00)
# car: (-10.3, 2.5, 14.48)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_30_drive_0016_sync_image_0000000224_image_02.png: 192x640 3 cars, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-11.6, 1.1, 15.60)
# car: (0.1, 0.4, 16.73)
# car: (-11.3, 1.1, 15.54)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000197_image_02.png: 192x640 9 cars, 2 vans, 1 misc, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.8, 1.3, 14.87)
# van: (-8.8, 0.5, 15.12)
# car: (-3.7, 0.8, 15.63)
# car: (-1.2, 0.7, 15.89)
# car: (-6.4, 0.8, 15.99)
# car: (-5.4, 0.6, 16.63)
# car: (-7.3, 0.6, 16.37)
# car: (-2.0, 0.4, 16.95)
# misc: (-3.2, 0.2, 17.10)
# car: (-10.9, 1.1, 14.71)
# van: (-4.1, 0.2, 15.93)
# car: (-12.0, 1.1, 14.85)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000326_image_02.png: 192x640 8 cars, 3 vans, 1 misc, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 640)
# car: (10.0, 2.0, 14.63)
# car: (9.3, 1.4, 14.56)
# car: (5.8, 0.7, 15.56)
# car: (-7.6, 0.6, 15.98)
# van: (1.8, 0.2, 17.17)
# car: (-3.5, 0.4, 16.04)
# car: (-4.5, 0.6, 16.08)
# van: (1.0, 0.1, 17.30)
# van: (-1.8, 0.0, 17.21)
# misc: (-6.9, 1.3, 14.86)
# car: (-6.3, 0.7, 15.08)
# car: (-11.5, 2.0, 14.46)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000569_image_02.png: 192x640 7 cars, 1 van, 2 miscs, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.1, 0.9, 15.10)
# car: (-5.0, 1.2, 14.61)
# misc: (-2.5, -0.0, 17.05)
# car: (-7.0, 0.9, 15.33)
# car: (-10.7, 0.9, 15.36)
# car: (-3.2, 0.7, 15.86)
# misc: (-1.3, -0.0, 17.23)
# van: (-5.4, 0.3, 16.78)
# car: (2.3, 0.4, 17.29)
# car: (1.0, 0.4, 16.92)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000104_image_02.png: 192x640 9 cars, 1 van, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.5, 2.2, 14.59)
# car: (-8.8, 1.4, 14.86)
# car: (-10.6, 1.8, 14.63)
# car: (3.7, 0.5, 16.64)
# car: (-5.5, 0.7, 15.05)
# van: (-4.3, 0.5, 15.94)
# car: (-4.9, 0.7, 15.30)
# car: (0.8, 0.4, 16.95)
# car: (-7.8, 1.1, 14.61)
# car: (0.4, 0.3, 17.02)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000443_image_02.png: 192x640 8 cars, 1 van, 1 misc, 8.1ms
# Speed: 0.9ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.7, 2.3, 14.44)
# van: (-3.8, 0.4, 16.70)
# car: (-7.0, 1.0, 15.26)
# car: (-5.6, 0.8, 16.04)
# car: (-0.5, 0.5, 16.58)
# car: (-9.0, 0.9, 14.78)
# car: (-2.4, 0.6, 16.45)
# car: (-2.1, 0.5, 16.56)
# misc: (-1.5, 0.3, 17.30)
# car: (-11.9, 1.9, 15.01)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0079_sync_image_0000000008_image_02.png: 192x640 2 cars, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-7.1, 1.9, 14.57)
# car: (1.5, 0.3, 16.42)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000371_image_02.png: 192x640 1 truck, 8.8ms
# Speed: 0.8ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.3, 0.0, 17.40)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000242_image_02.png: 192x640 14 cars, 2 cyclists, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.1, 1.7, 14.64)
# car: (3.2, 1.2, 14.45)
# car: (-7.6, 1.4, 14.93)
# car: (5.5, 0.8, 15.66)
# car: (-6.5, 1.1, 14.75)
# car: (-4.6, 0.8, 15.41)
# car: (-11.1, 2.2, 14.28)
# car: (1.0, 0.5, 17.03)
# car: (-5.8, 0.9, 14.79)
# car: (3.1, 0.5, 16.63)
# car: (-3.5, 0.4, 16.23)
# cyclist: (-1.0, 0.4, 17.32)
# car: (-5.4, 0.8, 14.82)
# car: (-3.9, 0.6, 16.04)
# car: (-4.4, 0.6, 15.83)
# cyclist: (-0.9, 0.4, 17.33)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0013_sync_image_0000000128_image_02.png: 192x640 2 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-0.2, 0.5, 17.13)
# car: (-13.0, 0.6, 17.07)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000458_image_02.png: 192x640 7 cars, 1 van, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.1, 1.7, 14.70)
# car: (-7.5, 2.3, 14.30)
# car: (-8.1, 1.4, 14.79)
# car: (-5.5, 1.1, 14.65)
# car: (-4.3, 0.9, 16.50)
# car: (-3.8, 0.9, 16.53)
# car: (0.9, 0.7, 17.14)
# van: (-2.8, 0.5, 17.14)
# truck: (0.5, 0.4, 17.40)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000215_image_02.png: 192x640 7 cars, 2 vans, 1 truck, 1 misc, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.0, 1.5, 14.74)
# car: (-5.1, 1.6, 14.49)
# car: (-0.6, 0.5, 16.24)
# car: (-3.5, 0.9, 15.02)
# misc: (-2.5, 0.2, 17.02)
# car: (-8.6, 0.7, 15.91)
# van: (-4.3, 0.3, 16.85)
# truck: (-1.8, -0.1, 17.20)
# car: (-6.0, 0.8, 14.49)
# van: (-11.4, 0.7, 14.62)
# car: (-10.0, 0.9, 14.76)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0013_sync_image_0000000014_image_02.png: 192x640 3 cars, 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (6.1, 1.9, 14.91)
# car: (-9.4, 0.5, 16.42)
# car: (-8.7, 0.5, 16.73)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000398_image_02.png: 192x640 2 cars, 1 truck, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.6, 1.4, 15.54)
# truck: (0.0, 0.1, 17.41)
# car: (-7.3, 0.9, 17.06)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000611_image_02.png: 192x640 8 cars, 1 misc, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.5, 1.9, 14.49)
# misc: (-4.5, 0.0, 17.05)
# car: (2.1, 0.7, 15.37)
# car: (-5.8, 1.0, 14.74)
# car: (4.0, 0.5, 16.65)
# car: (-8.0, 1.0, 14.54)
# car: (-7.4, 0.7, 15.88)
# car: (5.6, 0.3, 16.89)
# car: (-11.4, 1.7, 14.93)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000299_image_02.png: 192x640 (no detections), 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000041_image_02.png: 192x640 12 cars, 2 vans, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.9, 0.5, 14.92)
# car: (-2.9, 0.7, 15.35)
# car: (11.6, -0.2, 16.61)
# car: (-1.2, 0.5, 15.88)
# car: (1.3, 0.3, 16.23)
# car: (0.1, 0.4, 16.25)
# car: (10.7, -0.2, 16.47)
# car: (4.5, 0.1, 15.79)
# car: (-2.4, 0.6, 15.42)
# car: (8.1, -0.1, 16.89)
# car: (7.2, -0.2, 16.87)
# car: (10.2, -0.2, 16.64)
# van: (9.6, -0.2, 16.71)
# van: (9.9, -0.2, 16.63)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000167_image_02.png: 192x640 10 cars, 4 vans, 1 misc, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (4.1, 1.6, 14.77)
# car: (-8.5, 2.0, 14.49)
# car: (-4.3, 1.0, 15.16)
# van: (-10.3, 1.1, 14.51)
# van: (-6.9, 0.7, 15.48)
# car: (-3.3, 0.8, 15.85)
# car: (-0.6, 0.6, 16.07)
# car: (0.1, 0.5, 16.80)
# van: (-4.2, 0.4, 15.67)
# car: (-2.4, 0.5, 16.85)
# car: (-4.9, 0.6, 15.30)
# misc: (-1.0, 0.2, 17.27)
# van: (-2.0, 0.3, 17.11)
# car: (-2.9, 0.6, 15.90)
# car: (-1.0, 0.5, 16.24)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000557_image_02.png: 192x640 9 cars, 1 van, 2 miscs, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-5.6, 1.4, 14.63)
# car: (0.2, 0.8, 15.13)
# car: (-9.4, 1.3, 14.85)
# car: (-3.2, 0.7, 15.92)
# misc: (-1.9, -0.0, 17.10)
# misc: (-1.1, -0.0, 17.17)
# car: (-9.0, 0.8, 14.78)
# car: (-2.3, 0.5, 16.34)
# car: (-6.8, 0.6, 14.60)
# van: (-4.4, 0.3, 16.98)
# car: (-4.6, 0.6, 14.79)
# car: (1.1, 0.3, 17.05)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000101_image_02.png: 192x640 14 cars, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# car: (-9.1, 2.3, 14.59)
# car: (-4.5, 1.8, 14.80)
# car: (10.5, 1.3, 14.70)
# car: (-2.8, 1.2, 14.55)
# car: (3.3, 1.0, 14.58)
# car: (4.9, 0.6, 15.93)
# car: (-1.9, 0.7, 15.91)
# car: (8.5, 0.2, 16.71)
# car: (3.6, 0.7, 14.63)
# car: (-1.6, 0.7, 15.96)
# car: (-2.1, 0.3, 17.21)
# car: (3.8, 0.3, 16.50)
# car: (9.7, 0.4, 16.47)
# car: (3.6, 0.4, 14.95)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000020_image_02.png: 192x640 9 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (7.6, 1.0, 14.66)
# car: (-10.0, 0.6, 14.84)
# car: (3.3, 0.3, 16.11)
# car: (-9.2, 0.6, 14.83)
# car: (-6.3, 0.2, 15.92)
# car: (2.7, 0.2, 16.05)
# car: (-7.7, 0.4, 14.84)
# car: (-3.2, -0.3, 17.53)
# car: (-5.7, -0.0, 15.91)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0113_sync_image_0000000068_image_02.png: 192x640 3 cars, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (11.0, 1.5, 15.03)
# car: (10.1, 1.2, 14.51)
# car: (11.5, 1.9, 14.45)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000518_image_02.png: 192x640 1 truck, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.0, 0.0, 17.42)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000593_image_02.png: 192x640 8 cars, 2 vans, 2 miscs, 8.1ms
# Speed: 0.7ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# misc: (-6.7, -0.1, 16.16)
# car: (1.1, 0.8, 15.33)
# car: (-10.4, 1.5, 14.99)
# car: (-10.9, 2.4, 14.61)
# misc: (-2.0, -0.1, 17.25)
# car: (2.3, 0.5, 17.00)
# car: (-2.6, 0.5, 16.61)
# van: (-9.6, 0.7, 15.37)
# car: (4.0, 0.4, 17.24)
# car: (-3.0, 0.6, 16.27)
# van: (-11.7, 0.6, 14.84)
# car: (-11.2, 1.2, 14.62)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_10_03_drive_0047_sync_image_0000000191_image_02.png: 192x640 9 cars, 2 vans, 1 misc, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-10.4, 2.1, 14.71)
# car: (-7.8, 1.0, 15.27)
# car: (-1.1, 0.8, 15.69)
# car: (-10.0, 0.9, 15.37)
# car: (-5.9, 0.7, 16.34)
# car: (-3.3, 0.8, 15.73)
# van: (-8.1, 0.5, 15.46)
# car: (-5.1, 0.6, 16.53)
# car: (-7.1, 0.6, 16.70)
# van: (-4.4, 0.3, 16.94)
# car: (-2.2, 0.4, 16.86)
# misc: (-3.4, 0.2, 17.41)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0079_sync_image_0000000020_image_02.png: 192x640 1 car, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (0.3, 0.4, 16.04)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0023_sync_image_0000000026_image_02.png: 192x640 10 cars, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (9.1, 2.1, 14.63)
# car: (-10.0, 1.5, 14.62)
# car: (4.0, 0.9, 15.79)
# car: (-9.3, 1.1, 14.76)
# car: (-7.0, 0.8, 15.54)
# car: (3.1, 0.8, 15.61)
# car: (-6.3, 0.6, 15.62)
# car: (-3.3, 0.4, 17.44)
# car: (-5.5, 0.4, 15.80)
# car: (-11.1, 1.8, 14.64)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000797_image_02.png: 192x640 1 van, 1 truck, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# truck: (-0.2, -0.3, 16.54)
# van: (-0.2, -0.3, 16.61)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0095_sync_image_0000000080_image_02.png: 192x640 9 cars, 1 cyclist, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (-8.9, 2.3, 14.17)
# car: (8.4, 1.7, 14.61)
# car: (2.0, 0.9, 15.22)
# car: (-3.6, 0.9, 15.86)
# car: (0.9, 0.6, 16.24)
# car: (-3.0, 0.6, 16.64)
# car: (0.4, 0.4, 16.89)
# car: (-2.6, 0.5, 17.20)
# car: (-2.2, 0.4, 17.42)
# cyclist: (-1.3, 0.3, 17.51)
#
# image 1/1 /media/aditya/ExtraSpace/3D_Object_Detection/Dataset/image/2011_09_26_drive_0036_sync_image_0000000323_image_02.png: 192x640 1 car, 1 van, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
# car: (10.1, 0.8, 16.59)
# van: (10.1, 0.8, 16.59)
# Video saved at depth_video.avi
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
